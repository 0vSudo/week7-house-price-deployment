# %% [markdown]
# ## Task 1: Verify the Saved Model from week 6

# %%
import joblib

artifact = joblib.load("model/house_price_model_final.pkl")

print(type(artifact))
print(artifact.keys())
# Out:
# <class 'dict'>
# dict_keys(['model', 'selected_features', 'scaler', 'final_model_key', 'skewed_features', 'ordinal_cols', 'qual_map', 'tier_map', 'random_state'])

# %%
model = artifact["model"]
selected_features = artifact["selected_features"]
scaler = artifact["scaler"]

print(type(model))
print(len(selected_features))
# Out:
# <class 'lightgbm.sklearn.LGBMRegressor'>
# 35
